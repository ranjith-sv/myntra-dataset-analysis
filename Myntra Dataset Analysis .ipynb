# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
##loading a dataset

data = pd.read_csv("myntra.csv")

# %%
data
# Out:
#               id                                    name  \
# 0              1              Men Solid Oversized Cotton
# 1              2          Men Cotton Pure Cotton T-shirt
# 2              3               Women Pure Cotton T-shirt
# 3              4                Typography Print T-shirt
# 4              5  Printed Round Neck Pure Cotton T-shirt
# ...          ...                                     ...
# 1060208  1060209              Men Slim Tapered Fit Jeans
# 1060209  1060210                    Men Skinny Fit Jeans
# 1060210  1060211                      Men Printed Shorts
# 1060211  1060212                    Men Skinny Fit Jeans
# 1060212  1060213                               Men Jeans
#
#                                                        img asin   price  \
# 0        https://assets.myntassets.com/f_webp,dpr_1.0,q...    -   532.0
# 1        https://assets.myntassets.com/f_webp,dpr_1.0,q...    -   274.0
# ...

# %%
data.shape
# Out:
# (1060213, 11)

# %%
data.head()
# Out:
#    id                                    name  \
# 0   1              Men Solid Oversized Cotton
# 1   2          Men Cotton Pure Cotton T-shirt
# 2   3               Women Pure Cotton T-shirt
# 3   4                Typography Print T-shirt
# 4   5  Printed Round Neck Pure Cotton T-shirt
#
#                                                  img asin  price     mrp  \
# 0  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -  532.0  1299.0
# 1  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -  274.0   499.0
# 2  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -  551.0  1199.0
# 3  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -  296.0  1099.0
# 4  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -  494.0   899.0
#
#    rating  ratingTotal  discount                 seller  \
# 0     4.1         5300        59  Difference of Opinion
# 1     4.2        25400        45               Roadster
# 2     4.5         3400        54              DILLINGER
# ...

# %%
data.describe()
# Out:
#                  id         price           mrp        rating   ratingTotal  \
# count  1.060213e+06  1.060213e+06  1.060213e+06  1.060213e+06  1.060213e+06
# mean   5.301070e+05  1.536235e+03  2.668379e+03  1.060150e+00  4.189618e+01
# std    3.060573e+05  3.051140e+03  3.877900e+03  1.829632e+00  7.476645e+02
# min    1.000000e+00  2.500000e+01  2.500000e+01  0.000000e+00  0.000000e+00
# 25%    2.650540e+05  4.990000e+02  9.990000e+02  0.000000e+00  0.000000e+00
# 50%    5.301070e+05  8.110000e+02  1.780000e+03  0.000000e+00  0.000000e+00
# 75%    7.951600e+05  1.497000e+03  2.999000e+03  2.800000e+00  3.000000e+00
# max    1.060213e+06  2.575000e+05  2.575000e+05  5.000000e+00  7.640000e+04
#
#            discount
# count  1.060213e+06
# mean   1.496420e+02
# std    5.648781e+02
# min    0.000000e+00
# 25%    1.500000e+01
# 50%    5.000000e+01
# 75%    6.800000e+01
# max    1.999600e+04

# %%
myntra = data.copy() #changed data into myntra

# %%
myntra
# Out:
#               id                                    name  \
# 0              1              Men Solid Oversized Cotton
# 1              2          Men Cotton Pure Cotton T-shirt
# 2              3               Women Pure Cotton T-shirt
# 3              4                Typography Print T-shirt
# 4              5  Printed Round Neck Pure Cotton T-shirt
# ...          ...                                     ...
# 1060208  1060209              Men Slim Tapered Fit Jeans
# 1060209  1060210                    Men Skinny Fit Jeans
# 1060210  1060211                      Men Printed Shorts
# 1060211  1060212                    Men Skinny Fit Jeans
# 1060212  1060213                               Men Jeans
#
#                                                        img asin   price  \
# 0        https://assets.myntassets.com/f_webp,dpr_1.0,q...    -   532.0
# 1        https://assets.myntassets.com/f_webp,dpr_1.0,q...    -   274.0
# ...

# %%
#checking columns

myntra.columns
# Out:
# Index(['id', 'name', 'img', 'asin', 'price', 'mrp', 'rating', 'ratingTotal',
#        'discount', 'seller', 'purl'],
#       dtype='object')

# %% [markdown]
# # DROPPING UNWANTED COLUMNS

# %%
myntra.drop(['img'],axis=1,inplace=True) #axis = 1 ,removes columns

# %%
myntra.drop(['asin'],axis=1,inplace=True)

# %%
myntra.drop(['id'],axis=1,inplace=True)

# %%
myntra
# Out:
#                                            name   price     mrp  rating  \
# 0                    Men Solid Oversized Cotton   532.0  1299.0     4.1
# 1                Men Cotton Pure Cotton T-shirt   274.0   499.0     4.2
# 2                     Women Pure Cotton T-shirt   551.0  1199.0     4.5
# 3                      Typography Print T-shirt   296.0  1099.0     4.0
# 4        Printed Round Neck Pure Cotton T-shirt   494.0   899.0     4.2
# ...                                         ...     ...     ...     ...
# 1060208              Men Slim Tapered Fit Jeans  1199.0  2399.0     4.3
# 1060209                    Men Skinny Fit Jeans   574.0  2299.0     3.8
# 1060210                      Men Printed Shorts   799.0  1599.0     3.9
# 1060211                    Men Skinny Fit Jeans  1199.0  1999.0     3.8
# 1060212                               Men Jeans   835.0  2199.0     0.0
#
#          ratingTotal  discount                 seller  \
# ...

# %% [markdown]
# # RENAME COLUMNS

# %%
myntra.rename(columns={"seller":"brand"},inplace=True) #inplace = true, means just a conformation for a data to change

# %%
myntra.rename(columns={"purl":"url"},inplace=True)

# %%
myntra
# Out:
#                                            name   price     mrp  rating  \
# 0                    Men Solid Oversized Cotton   532.0  1299.0     4.1
# 1                Men Cotton Pure Cotton T-shirt   274.0   499.0     4.2
# 2                     Women Pure Cotton T-shirt   551.0  1199.0     4.5
# 3                      Typography Print T-shirt   296.0  1099.0     4.0
# 4        Printed Round Neck Pure Cotton T-shirt   494.0   899.0     4.2
# ...                                         ...     ...     ...     ...
# 1060208              Men Slim Tapered Fit Jeans  1199.0  2399.0     4.3
# 1060209                    Men Skinny Fit Jeans   574.0  2299.0     3.8
# 1060210                      Men Printed Shorts   799.0  1599.0     3.9
# 1060211                    Men Skinny Fit Jeans  1199.0  1999.0     3.8
# 1060212                               Men Jeans   835.0  2199.0     0.0
#
#          ratingTotal  discount                  brand  \
# ...

# %% [markdown]
# # CHECKING DATATYPES

# %%
myntra.dtypes
# Out:
# name            object
# price          float64
# mrp            float64
# rating         float64
# ratingTotal      int64
# discount         int64
# brand           object
# url             object
# dtype: object

# %%
myntra.isna()
# Out:
#           name  price    mrp  rating  ratingTotal  discount  brand    url
# 0        False  False  False   False        False     False  False  False
# 1        False  False  False   False        False     False  False  False
# 2        False  False  False   False        False     False  False  False
# 3        False  False  False   False        False     False  False  False
# 4        False  False  False   False        False     False  False  False
# ...        ...    ...    ...     ...          ...       ...    ...    ...
# 1060208  False  False  False   False        False     False  False  False
# 1060209  False  False  False   False        False     False  False  False
# 1060210  False  False  False   False        False     False  False  False
# 1060211  False  False  False   False        False     False  False  False
# 1060212  False  False  False   False        False     False  False  False
#
# [1060213 rows x 8 columns]

# %%
myntra.isna().sum()
# Out:
# name           0
# price          0
# mrp            0
# rating         0
# ratingTotal    0
# discount       0
# brand          0
# url            0
# dtype: int64

# %% [markdown]
# # CHECKING UNIQUE VALUES

# %%
myntra.name.unique()
# Out:
# array(['Men Solid Oversized Cotton', 'Men Cotton Pure Cotton T-shirt',
#        'Women Pure Cotton T-shirt', ..., 'Slim Fit Twill Joggers',
#        'Men VK AOP Chino Shorts',
#        'Men Checked Slim Fit Cotton Track Pants'], dtype=object)

# %%
myntra.url.unique()
# Out:
# array(['https://www.myntra.com/tshirts/difference-of-opinion/difference-of-opinion-men-mint-green-round-neck-drop-shoulder-sleeves-cotton-loose-t-shirt/16407468/buy',
#        'https://www.myntra.com/tshirts/roadster/roadster-men-black-cotton-pure-cotton-t-shirt/1996777/buy',
#        'https://www.myntra.com/tshirts/dillinger/dillinger-women-navy-blue-typography-printed-pure-cotton-t-shirt/15598180/buy',
#        ...,
#        'https://www.myntra.com/jeans/mast--harbour/mast--harbour-men-blue-skinny-fit-low-distress-light-fade-acid-wash-jeans/18452958/buy',
#        'https://www.myntra.com/jeans/roadster/roadster-men-grey-skinny-fit-mid-rise-clean-look-stretchable-jeans/8895025/buy',
#        'https://www.myntra.com/jeans/ivoc/ivoc-men-black-jean-stretchable-jeans/17535248/buy'],
#       dtype=object)

# %%
myntra.name[0]
# Out:
# 'Men Solid Oversized Cotton'

# %%
myntra.url[0]
# Out:
# 'https://www.myntra.com/tshirts/difference-of-opinion/difference-of-opinion-men-mint-green-round-neck-drop-shoulder-sleeves-cotton-loose-t-shirt/16407468/buy'

# %%
myntra["category"]=myntra['url'].apply(lambda x : x.split('/')[3])

# %%
myntra
# Out:
#                                            name   price     mrp  rating  \
# 0                    Men Solid Oversized Cotton   532.0  1299.0     4.1
# 1                Men Cotton Pure Cotton T-shirt   274.0   499.0     4.2
# 2                     Women Pure Cotton T-shirt   551.0  1199.0     4.5
# 3                      Typography Print T-shirt   296.0  1099.0     4.0
# 4        Printed Round Neck Pure Cotton T-shirt   494.0   899.0     4.2
# ...                                         ...     ...     ...     ...
# 1060208              Men Slim Tapered Fit Jeans  1199.0  2399.0     4.3
# 1060209                    Men Skinny Fit Jeans   574.0  2299.0     3.8
# 1060210                      Men Printed Shorts   799.0  1599.0     3.9
# 1060211                    Men Skinny Fit Jeans  1199.0  1999.0     3.8
# 1060212                               Men Jeans   835.0  2199.0     0.0
#
#          ratingTotal  discount                  brand  \
# ...

# %%
myntra.url[0]
# Out:
# 'https://www.myntra.com/tshirts/difference-of-opinion/difference-of-opinion-men-mint-green-round-neck-drop-shoulder-sleeves-cotton-loose-t-shirt/16407468/buy'

# %% [markdown]
# # ADDING DESCRIPTION FOR PRODUCTS

# %%
myntra['description']=myntra['url'].apply(lambda x : x .split('/')[-3])

# %%
myntra
# Out:
#                                            name   price     mrp  rating  \
# 0                    Men Solid Oversized Cotton   532.0  1299.0     4.1
# 1                Men Cotton Pure Cotton T-shirt   274.0   499.0     4.2
# 2                     Women Pure Cotton T-shirt   551.0  1199.0     4.5
# 3                      Typography Print T-shirt   296.0  1099.0     4.0
# 4        Printed Round Neck Pure Cotton T-shirt   494.0   899.0     4.2
# ...                                         ...     ...     ...     ...
# 1060208              Men Slim Tapered Fit Jeans  1199.0  2399.0     4.3
# 1060209                    Men Skinny Fit Jeans   574.0  2299.0     3.8
# 1060210                      Men Printed Shorts   799.0  1599.0     3.9
# 1060211                    Men Skinny Fit Jeans  1199.0  1999.0     3.8
# 1060212                               Men Jeans   835.0  2199.0     0.0
#
#          ratingTotal  discount                  brand  \
# ...

# %%
myntra.description.unique()
# Out:
# array(['difference-of-opinion-men-mint-green-round-neck-drop-shoulder-sleeves-cotton-loose-t-shirt',
#        'roadster-men-black-cotton-pure-cotton-t-shirt',
#        'dillinger-women-navy-blue-typography-printed-pure-cotton-t-shirt',
#        ...,
#        'the-indian-garage-co-men-charcoal-slim-fit-low-distress-light-fade-stretchable-jeans',
#        'mash-unlimited-men-grey-melange-solid-slim-fit-cotton-track-pant',
#        'mast--harbour-men-blue-skinny-fit-low-distress-light-fade-acid-wash-jeans'],
#       dtype=object)

# %%
myntra.groupby('name')

# %%
myntra.groupby("name").agg({'category':pd.Series.mode}) #pd.Series.mode : modes of series in sorted order
# Out:
#                                    category
# name
#  Boys Top with Pyjamas           kurta-sets
#  Bralette Bra                           bra
#  Eyeshadow Palette                eyeshadow
# !28 TC Cotton Bedsheet            bedsheets
# "Selfie Wala Bhai" Rakhi              rakhi
# ...                                     ...
# x RCB Arcade T-shirt                tshirts
# x The Lion King Eyeshadow         eyeshadow
# x Women Black Analogue Watch        watches
# x1Der Core Pants II             track-pants
# xThebe Magugu 000 T Sweatshirt  sweatshirts
#
# [217738 rows x 1 columns]

# %%
myntra.groupby('name').agg({'category':pd.Series.mode}).head()
# Out:
#                             category
# name
#  Boys Top with Pyjamas    kurta-sets
#  Bralette Bra                    bra
#  Eyeshadow Palette         eyeshadow
# !28 TC Cotton Bedsheet     bedsheets
# "Selfie Wala Bhai" Rakhi       rakhi

# %%
myntra.loc[myntra.name =='-']
# Out:
#        name   price     mrp  rating  ratingTotal  discount  \
# 127529    -   629.0  1399.0     0.0            0        55
# 159257    -   987.0  1299.0     4.5            4        24
# 173765    -  2799.0  2799.0     0.0            0         0
# 175247    -   269.0   899.0     4.4          363        70
# 182836    -   479.0  1598.0     0.0            0        70
# ...     ...     ...     ...     ...          ...       ...
# 815810    -   780.0   780.0     0.0            0         0
# 815819    -   307.0   699.0     4.2           20        56
# 815821    -   780.0   780.0     0.0            0         0
# 816739    -  1160.0  1160.0     0.0            0         0
# 857270    -  1799.0  1799.0     0.0            0         0
#
#                          brand  \
# 127529                JUMP USA
# 159257                  DChica
# 173765                    ONLY
# 175247  Kook N Keech Star Wars
# 182836            Leading Lady
# ...                        ...
# ...

# %%
myntra[myntra['name']=='-'].groupby('category').agg({'name':pd.Series.mode})
# Out:
#          name
# category
# bra         -
# caps        -
# tshirts     -

# %% [markdown]
# # REPLACING NAME BY ITS CATEGORY

# %%
myntra.loc[myntra['name']=="-",'name']
# Out:
# 127529    -
# 159257    -
# 173765    -
# 175247    -
# 182836    -
#          ..
# 815810    -
# 815819    -
# 815821    -
# 816739    -
# 857270    -
# Name: name, Length: 806, dtype: object

# %%
myntra.loc[myntra['name']=='-','name'] = myntra.loc[myntra['name']=='-','url']

# %%
myntra
# Out:
#                                            name   price     mrp  rating  \
# 0                    Men Solid Oversized Cotton   532.0  1299.0     4.1
# 1                Men Cotton Pure Cotton T-shirt   274.0   499.0     4.2
# 2                     Women Pure Cotton T-shirt   551.0  1199.0     4.5
# 3                      Typography Print T-shirt   296.0  1099.0     4.0
# 4        Printed Round Neck Pure Cotton T-shirt   494.0   899.0     4.2
# ...                                         ...     ...     ...     ...
# 1060208              Men Slim Tapered Fit Jeans  1199.0  2399.0     4.3
# 1060209                    Men Skinny Fit Jeans   574.0  2299.0     3.8
# 1060210                      Men Printed Shorts   799.0  1599.0     3.9
# 1060211                    Men Skinny Fit Jeans  1199.0  1999.0     3.8
# 1060212                               Men Jeans   835.0  2199.0     0.0
#
#          ratingTotal  discount                  brand  \
# ...

# %%
myntra.columns
# Out:
# Index(['name', 'price', 'mrp', 'rating', 'ratingTotal', 'discount', 'brand',
#        'url', 'category', 'description'],
#       dtype='object')

# %%
myntra.discount.unique()
# Out:
# array([  59,   45,   54, ..., 1253, 4440, 6401], dtype=int64)

# %%
myntra
# Out:
#                                            name   price     mrp  rating  \
# 0                    Men Solid Oversized Cotton   532.0  1299.0     4.1
# 1                Men Cotton Pure Cotton T-shirt   274.0   499.0     4.2
# 2                     Women Pure Cotton T-shirt   551.0  1199.0     4.5
# 3                      Typography Print T-shirt   296.0  1099.0     4.0
# 4        Printed Round Neck Pure Cotton T-shirt   494.0   899.0     4.2
# ...                                         ...     ...     ...     ...
# 1060208              Men Slim Tapered Fit Jeans  1199.0  2399.0     4.3
# 1060209                    Men Skinny Fit Jeans   574.0  2299.0     3.8
# 1060210                      Men Printed Shorts   799.0  1599.0     3.9
# 1060211                    Men Skinny Fit Jeans  1199.0  1999.0     3.8
# 1060212                               Men Jeans   835.0  2199.0     0.0
#
#          ratingTotal  discount                  brand  \
# ...

# %% [markdown]
# # DROPPING URL COLUMNS

# %%
myntra_df = myntra.copy()

# %%
myntra_df
# Out:
#                                            name   price     mrp  rating  \
# 0                    Men Solid Oversized Cotton   532.0  1299.0     4.1
# 1                Men Cotton Pure Cotton T-shirt   274.0   499.0     4.2
# 2                     Women Pure Cotton T-shirt   551.0  1199.0     4.5
# 3                      Typography Print T-shirt   296.0  1099.0     4.0
# 4        Printed Round Neck Pure Cotton T-shirt   494.0   899.0     4.2
# ...                                         ...     ...     ...     ...
# 1060208              Men Slim Tapered Fit Jeans  1199.0  2399.0     4.3
# 1060209                    Men Skinny Fit Jeans   574.0  2299.0     3.8
# 1060210                      Men Printed Shorts   799.0  1599.0     3.9
# 1060211                    Men Skinny Fit Jeans  1199.0  1999.0     3.8
# 1060212                               Men Jeans   835.0  2199.0     0.0
#
#          ratingTotal  discount                  brand  \
# ...

# %%
myntra_df.columns
# Out:
# Index(['name', 'price', 'mrp', 'rating', 'ratingTotal', 'discount', 'brand',
#        'url', 'category', 'description'],
#       dtype='object')

# %%
myntra_df.head()
# Out:
#                                      name  price     mrp  rating  ratingTotal  \
# 0              Men Solid Oversized Cotton  532.0  1299.0     4.1         5300
# 1          Men Cotton Pure Cotton T-shirt  274.0   499.0     4.2        25400
# 2               Women Pure Cotton T-shirt  551.0  1199.0     4.5         3400
# 3                Typography Print T-shirt  296.0  1099.0     4.0        18400
# 4  Printed Round Neck Pure Cotton T-shirt  494.0   899.0     4.2         3800
#
#    discount                  brand  \
# 0        59  Difference of Opinion
# 1        45               Roadster
# 2        54              DILLINGER
# 3        73                Huetrap
# 4        45               Roadster
#
#                                                  url category  \
# 0  https://www.myntra.com/tshirts/difference-of-o...  tshirts
# 1  https://www.myntra.com/tshirts/roadster/roadst...  tshirts
# 2  https://www.myntra.com/tshirts/dillinger/dilli...  tshirts
# ...

# %% [markdown]
# # CHECKING DUPLICATES

# %%
myntra_df.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1060208    False
# 1060209    False
# 1060210     True
# 1060211    False
# 1060212    False
# Length: 1060213, dtype: bool

# %%
myntra_df.duplicated().sum()
# Out:
# 228515

# %% [markdown]
# # DROPPING DUPLICATES

# %%
myntra_df.drop_duplicates(inplace = True)

# %%
myntra_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # DISCOUNT COLUMN

# %%
myntra_df.loc[myntra_df['discount'].apply(lambda x: len(str(x)))>2,['mrp','price','discount']]
# Out:
#             mrp   price  discount
# 53       2499.0   847.0      1652
# 58       1049.0   749.0       300
# 94       1199.0   625.0       574
# 106      1699.0   645.0      1054
# 111      1699.0   465.0      1234
# ...         ...     ...       ...
# 1059949  7999.0  1199.0      6800
# 1059963  1899.0   899.0      1000
# 1059994  1649.0   499.0      1150
# 1060176  1699.0   499.0      1200
# 1060181  1599.0   699.0       900
#
# [65929 rows x 3 columns]

# %%
myntra_df.loc[myntra_df['discount'].apply(lambda x : len(str(x)))>2,['mrp','price','discount']].head()
# Out:
#         mrp  price  discount
# 53   2499.0  847.0      1652
# 58   1049.0  749.0       300
# 94   1199.0  625.0       574
# 106  1699.0  645.0      1054
# 111  1699.0  465.0      1234

# %%
myntra_df.loc[myntra_df['discount'].apply(lambda x :len(str(x)))<2,['mrp','price','discount']]
# Out:
#             mrp   price  discount
# 25       1699.0  1699.0         0
# 36        699.0   699.0         0
# 54       1999.0  1999.0         0
# 56       1649.0  1649.0         0
# 59       1449.0  1449.0         0
# ...         ...     ...       ...
# 1060157  1899.0  1899.0         0
# 1060167  1999.0  1999.0         0
# 1060168  1799.0  1799.0         0
# 1060170  1799.0  1799.0         0
# 1060174   899.0   899.0         0
#
# [163402 rows x 3 columns]

# %%
myntra_df.loc[myntra_df['discount'].apply(lambda x:len(str(x)))<2,['mrp','price','discount']].head()
# Out:
#        mrp   price  discount
# 25  1699.0  1699.0         0
# 36   699.0   699.0         0
# 54  1999.0  1999.0         0
# 56  1649.0  1649.0         0
# 59  1449.0  1449.0         0

# %%
myntra_df.discount.unique()
# Out:
# array([  59,   45,   54, ..., 1253, 4440, 6401], dtype=int64)

# %%
myntra_df.discount.unique()[0:50]
# Out:
# array([  59,   45,   54,   73,   86,   50,   60,   40,   42,   75,   55,
#          58,    0,   30,   65,   10,   18,   35,   70,   20, 1652,   62,
#          25,  300,    5,   67,   68,   38,   36,  574,   69, 1054,   72,
#        1234,   80,   66,   61,   85,   82,   84,  700,   88,   77,   90,
#          48,   56,   28,   41,   76,   63], dtype=int64)

# %%
def discounut_percent(x):
    
    return(100*x[1]//x[0])

myntra_df.loc[myntra_df.loc9['discount']>90,'discount'] = myntra_df.loc[myntra_df['discount']>90,['mrp','discount']].apply(discount_percent, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 5
#       1 def discounut_percent(x):
#       3     return(100*x[1]//x[0])
# ----> 5 myntra_df.loc[myntra_df.loc9['discount']>90,'discount'] = myntra_df.loc[myntra_df['discount']>90,['mrp','discount']].apply(discount_percent, axis = 1)
#
# NameError: name 'discount_percent' is not defined

# %%
myntra_df.discount.unique()

# %% [markdown]
# # CHECKING DUPLICATES

# %%
myntra_df.duplicated()

# %%
myntra_df.duplicated().sum()

# %%
myntra_df.drop_duplicates(inplace = True)

# %%
myntra_df

# %% [markdown]
# # DATA: RATING = 0

# %%
myntra_df[myntra_df['rating'] == 0]

# %%
myntra_df[myntra_df['rating']>4]

# %%
myntra_df[myntra_df['rating']>4].sum()

# %%
myntra_df[(myntra_df['brand']== "Adidas" )].sum()

# %%
myntra_df[(myntra_df['brand'] == 'Flying Machine')]

# %%
myntra_df[(myntra_df['brand']=='Flying Machine') & (myntra_df['category']=='shirts')]

# %%
myntra_df[(myntra_df['brand'] == 'Difference of Opinion') & (myntra_df['category'] == 'tshirts')]

# %%
myntra_df[(myntra_df['brand'] == 'Difference of Opinion')  & (myntra_df['category'] == 'tshirts') & (myntra_df['rating'] >4.5)]

# %%
zero_rating = myntra_df.loc[myntra_df['rating'] == 0,'brand'].value_counts()

# %%
zero_rating

# %% [markdown]
# # BRAND WHICH HAVING ZERO RATING

# %%
zero_rating[0:10].plot(kind = "bar")

# %% [markdown]
# # CODE FOR PRODUCT SEARCH

# %%
def product_sugg(product_category,brand_name,budget):
    
    display(myntra_df[(myntra_df['category'] == product_category) & (myntra_df['brand'] == brand_name) & (myntra_df['price']<=budget)].sort_values(by = 'rating', ascending = False),'Welcome...')
    
    
product_category = input('Enter Your Category')
brand_name = input('Enter the BRand You Want')
budget = float(input('Enter Your Budget'))

product_sugg(product_category,brand_name,budget)

# %% [markdown]
# # DATA VISUALISATION

# %%
# !pip install seaborn

# %%
# !pip install matplotlib

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# %matplotlib inline

# %%
sns.heatmap(myntra_df.corr(numeric_only=True),linewidths=0.5, linecolor="white")
# Out:
# <Axes: >

# %%
#mrp and price are hightly corelated to each other

# %%
sns.histplot(kde=True,data=myntra_df,x='mrp',bins=60,log_scale=True)
# Out:
# <Axes: xlabel='mrp', ylabel='Count'>

# %%
#Most of the mrp rate are approx in range of Rs.900 to Rs. 3000

# %%
sns.histplot(kde=True,data=myntra_df,x='price',bins=60, log_scale=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
#most of the product selling price are approx from Rs. 600 to Rs. 1000

# %%
sns.histplot(kde=True,data=myntra_df,x='discount',bins=60)
# Out:
# <Axes: xlabel='discount', ylabel='Count'>

# %%
#if you're looking overall discount most of the products having no discount or having approx 50-60% discount

# %%
sns.histplot(kde=True,data=myntra_df,x='rating',bins=60)
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
#most of the products have zero rating

# %% [markdown]
# # barplot for category column by value_counts

# %%
s = myntra.category.value_counts().reset_index()
h= s.head(10)
t = s.tail(10)

# %%
fig,axes = plt.subplots(nrows=1, ncols=2, figsize=(12,5))   
fig.subplots_adjust(bottom=0.2, left=0.2)

s = sns.barplot(data=h,y='index',x='category',ax=axes[0])
s.set_xlabel('Count')
s.set_ylabel('Product Category')
s.set_title('Max product Categories')

s1 = sns.barplot(data=t,y='index',x='category',ax=axes[1])
s1.set_xlabel('Count')
s1.set_ylabel('Product Category')
s1.set_title('Min product Category')


plt.tight_layout(pad=2)

# %% [markdown]
# # CHECKING OUTLIERS IN MRP'S AND PRICE

# %%
plt.figure(figsize=(9,12))
sns.boxplot(myntra_df[["mrp","price"]])
# Out:
# <Axes: >

# %% [markdown]
# # TOP BRANDS BY INFLUENCE

# %%
m = myntra['brand'].value_counts().head(20).reset_index()

# %%
plt.figure(figsize=(8,9))
s = sns.barplot(data=m,y='index',x='brand')
s.set_xlabel('Count')
s.set_ylabel('brand')
# Out:
# Text(0, 0.5, 'brand')
